# %%
import pandas as pd

url = f"https://dluberprojectdevf.blob.core.windows.net/raw/injestion/map_cities.json?sp=r&st=2026-06-30T10:59:36Z&se=2026-06-30T19:14:36Z&spr=https&sv=2026-02-06&sr=c&sig=Xa2vFCvLmdKdNrP%2FWaw5w4BfLdNH7ybykZCK0FcR2%2BE%3D"

df=pd.read_json(url)
df_spark=spark.createDataFrame(df)
display(df_spark)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
import pandas as pd

files= [

  {
    "file": "map_cancellation_reasons"
  },
  {
    "file": "map_cities"
  },
  {
    "file": "map_payment_methods"
  },
  {
    "file": "map_ride_statuses"
  },
  {
    "file": "map_vehicle_makes"
  },
  {
    "file": "map_vehicle_types"
  }
]

for file in files:
    
    url = f"https://dluberprojectdevf.blob.core.windows.net/raw/injestion/{file['file']}.json?sp=r&st=2026-07-11T05:47:16Z&se=2026-07-12T14:02:16Z&spr=https&sv=2026-02-06&sr=c&sig=ecgoz9KS4hxMSuj9usorMjKAoeF08Zsnmqsos%2FOoD4k%3D"

    df=pd.read_json(url)
    df_spark=spark.createDataFrame(df)
    df_spark.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable(f"uber.bronze.{file['file']}")

# %%
url = f"https://dluberprojectdevf.blob.core.windows.net/raw/injestion/bulk_rides.json?sp=r&st=2026-06-28T07:19:33Z&se=2026-07-01T15:34:33Z&spr=https&sv=2026-02-06&sr=c&sig=sggrrEiK%2FTMCL4l0eBEsV0L2da1V0PJ7olGomA6BEYk%3D"
 
df=pd.read_json(url)
df_spark=spark.createDataFrame(df)
if not spark.catalog.tableExists("uber.bronze.bulk_rides"):
        df_spark.write.format("delta")\
            .mode("overwrite")\
            .saveAsTable(f"uber.bronze.bulk_rides")
        print("This will not run more than 1 time")

# %%
# %sql
SELECT * FROM uber.bronze.map_cities;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
